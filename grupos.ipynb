# %%
import pandas as pd
import numpy as np
import JMPEstadisticas as jmp

# %%
notas_df = pd.read_csv('output.csv')

# %%
observaciones = notas_df

# %%
stats = jmp.JMPEstadisticas(observaciones['NOTAS'])
resultados = stats.analisisCaracteristica()
# Out:
# -----------------------------------------
#       MEDIDA DE TENDENCIA CENTRAL
# -----------------------------------------
#
# -- CANTIDAD DE OBSERVACIONES --
# Cantidad de observaciones = 16
#
# -- MIN --
# Valor mínimo: 3.0
#
# -- MAX --
# Valor máximo: nan
#
# -- MEDIA --
# Media aritmética calculada = nan
# > Observaciones: Si todas las observaciones tuvieran el mismo valor (reparto equitativo), este sería nan
#
# -- MEDIANA --
# La cantidad de observaciones es par.
# RANGO = 8.0
# Mediana calculada = 12.0
# > Observaciones: El valor que se encuentra en el punto medio de las observaciones es:12.0
# El reparto es: 8.0 valores en cada lado de la mediana
#
# -- MODA --
# Counter({12.0: 3, 11.0: 3, 14.0: 2, 3.0: 1, 19.0: 1, 10.0: 1, 15.0: 1, 9.0: 1, 8.0: 1, 13.0: 1, 16.0: 1, nan: 1, nan: 1, nan: 1, nan: 1})
# > Observacions: La moda permite determinar los valores observados con más frecuencia
#
#
# -----------------------------------------
#       MEDIDA DE DISPERSION
# ...

# %%
stats.analisisCaracteristica()
# Out:
# -----------------------------------------
#       MEDIDA DE TENDENCIA CENTRAL
# -----------------------------------------
#
# -- CANTIDAD DE OBSERVACIONES --
# Cantidad de observaciones = 16
#
# -- MIN --
# Valor mínimo: 3.0
#
# -- MAX --
# Valor máximo: nan
#
# -- MEDIA --
# Media aritmética calculada = nan
# > Observaciones: Si todas las observaciones tuvieran el mismo valor (reparto equitativo), este sería nan
#
# -- MEDIANA --
# La cantidad de observaciones es par.
# RANGO = 8.0
# Mediana calculada = 12.0
# > Observaciones: El valor que se encuentra en el punto medio de las observaciones es:12.0
# El reparto es: 8.0 valores en cada lado de la mediana
#
# -- MODA --
# Counter({12.0: 3, 11.0: 3, 14.0: 2, 3.0: 1, 19.0: 1, 10.0: 1, 15.0: 1, 9.0: 1, 8.0: 1, 13.0: 1, 16.0: 1, nan: 1, nan: 1, nan: 1, nan: 1})
# > Observacions: La moda permite determinar los valores observados con más frecuencia
#
#
# -----------------------------------------
#       MEDIDA DE DISPERSION
# ...
